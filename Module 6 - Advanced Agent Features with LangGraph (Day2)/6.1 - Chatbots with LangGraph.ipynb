# %% [markdown]
# # Building a Chatbot

# %% [markdown]
# ## Simple Chatbot

# %%
from IPython.display import Image, display
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import AIMessage, HumanMessage
from dotenv import load_dotenv
import os

# %%
load_dotenv(override=True)
# Out:
# True

# %%
#Check for environment variables
def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

# %%
#Make sure this exists
_set_env("GROQ_API_KEY")

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
class SimpleChatState(TypedDict):
    messages: Annotated[list, add_messages]

# %%
def simple_chatbot(state: SimpleChatState):
    return {
        "messages": [llm.invoke(state["messages"])]
    }

# %%
graph = StateGraph(SimpleChatState)

graph.add_node("simple_chatbot", simple_chatbot)
graph.set_entry_point("simple_chatbot")
graph.add_edge("simple_chatbot", END)

app = graph.compile()

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
while True: 
    user_input = input("User: ")
    if(user_input in ["exit", "end"]):
        break
    else: 
        result = app.invoke({
            "messages": [HumanMessage(content=user_input)]
        })

        print("AI: " + result["messages"][-1].content + "\n")
# Out:
# AI: Hello. How can I assist you today?

# %% [markdown]
# ## Adding Tools

# %%
from IPython.display import Image, display
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import AIMessage, HumanMessage
from dotenv import load_dotenv
from langchain_tavily import TavilySearch
from langgraph.prebuilt import ToolNode, tools_condition

# %%
class SimpleChatState(TypedDict):
    messages: Annotated[list, add_messages]

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
search_tool = TavilySearch(max_results=2)
tools = [search_tool]

# %%
llm_with_tools = llm.bind_tools(tools=tools)

# %%
def tool_enabled_chatbot(state: SimpleChatState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

# %% [markdown]
# We use the [built-in `ToolNode`](https://langchain-ai.github.io/langgraph/reference/prebuilt/?h=tools+condition#toolnode) and simply pass a list of our tools to initialize it.

# %%
tool_node = ToolNode(tools=tools)

# %% [markdown]
# We can also use the [built-in `tools_condition`](https://langchain-ai.github.io/langgraph/reference/prebuilt/?h=tools+condition#tools_condition) as our conditional edge. Here - we first define a custom router for explanation, but show a streamlined manner just using `tools_condition`.

# %%
#From scratch - else use tools_condition
def tools_router(state: SimpleChatState):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tools"
    else: 
        return "end"

# %%
#From scratch - else use tools_condition
graph = StateGraph(SimpleChatState)

graph.add_node("chatbot", tool_enabled_chatbot)
graph.add_node("tools", tool_node)
graph.set_entry_point("chatbot")

graph.add_conditional_edges("chatbot", 
                            tools_router,
                           {
                               "tools": "tools",
                               "end": END
                           })
graph.add_edge("tools", "chatbot")

app = graph.compile()

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
#Using tools_condition
graph = StateGraph(SimpleChatState)

graph.add_node("chatbot", tool_enabled_chatbot)
graph.add_node("tools", tool_node)
graph.set_entry_point("chatbot")

graph.add_conditional_edges("chatbot", 
                            tools_condition)
graph.add_edge("tools", "chatbot")

app = graph.compile()

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
while True: 
    user_input = input("User: ")
    if(user_input in ["exit", "end"]):
        break
    else: 
        result = app.invoke({
            "messages": [HumanMessage(content=user_input)]
        })

        print("AI: " + result["messages"][-1].content + "\n")
# Out:
# AI: The current PM of India is Narendra Modi.

# %% [markdown]
# **Question** Who returns a ToolMessage?

# %% [markdown]
# ## Adding Memory

# %% [markdown]
# **We are referring to short-term memory enabled by thread-level persistence here below, and not long-term memory which is across user or applications.**

# %%
from IPython.display import Image, display
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import AIMessage, HumanMessage
from dotenv import load_dotenv
from langchain_tavily import TavilySearch
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.checkpoint.memory import InMemorySaver

# %%
memory = InMemorySaver()

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
search_tool = TavilySearch(max_results=2)
tools = [search_tool]

# %%
llm_with_tools = llm.bind_tools(tools=tools)

# %%
tool_node = ToolNode(tools=tools)

# %%
class SimpleChatState(TypedDict):
    messages: Annotated[list, add_messages]

# %%
def tool_enabled_chatbot(state: SimpleChatState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

# %%
#From scratch - else use tools_condition
graph = StateGraph(SimpleChatState)

graph.add_node("chatbot", tool_enabled_chatbot)
graph.add_node("tools", tool_node)
graph.set_entry_point("chatbot")

graph.add_conditional_edges("chatbot", 
                            tools_condition)

graph.add_edge("tools", "chatbot")

app = graph.compile(checkpointer=memory)

config = {"configurable": {
    "thread_id": 1
}}

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
while True: 
    user_input = input("User: ")
    if(user_input in ["exit", "end"]):
        break
    else: 
        result = app.invoke({
            "messages": [HumanMessage(content=user_input)]
        }, config=config)

        print("AI: " + result["messages"][-1].content)
# Out:
# AI: I'm a large language model, I don't have the ability to remember past conversations or maintain a memory of individual users. Each time you interact with me, it's a new conversation, and I don't retain any information from previous chats.

# %% [markdown]
# **With short-term memory, long conversations can lead to context length being exceeded. Common counteractions include trimming, deleting, summarizing messages and managing checkpoints.**

# %% [markdown]
# ### Use in Production

# %% [markdown]
# **In production, we should use a checkpointer backed by a database.**

# %%
from IPython.display import Image, display
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
from langchain_tavily import TavilySearch
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.checkpoint.sqlite import SqliteSaver
import sqlite3 #in built with Python

# %%
#Create a connection string
# !mkdir checkpoints
sqlite_conn = sqlite3.connect("checkpoints/checkpoint.sqlite", check_same_thread=False)

# Note: check_same_thread=False is OK as the implementation uses a lock to ensure thread safety.
# Out:
# mkdir: checkpoints: File exists

# %%
#Replace memory saver with SqliteSaver - everything else is same
memory = SqliteSaver(sqlite_conn)

# %% [markdown]
# **After every single node execution, this checkpointer will append new checkpoints and save the state.**

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
search_tool = TavilySearch(max_results=2)
tools = [search_tool]

# %%
llm_with_tools = llm.bind_tools(tools=tools)

# %%
tool_node = ToolNode(tools=tools)

# %%
class SimpleChatState(TypedDict):
    messages: Annotated[list, add_messages]

# %%
def tool_enabled_chatbot(state: SimpleChatState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

# %%
#From scratch - else use tools_condition
graph = StateGraph(SimpleChatState)

graph.add_node("chatbot", tool_enabled_chatbot)
graph.add_node("tools", tool_node)
graph.set_entry_point("chatbot")

graph.add_conditional_edges("chatbot", 
                            tools_condition)

graph.add_edge("tools", "chatbot")

app = graph.compile(checkpointer=memory)

config = {"configurable": {
    "thread_id": 1
}}

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
#Running again, it is able to recall - but after deleting SQLite, it'll not be able to recall
while True: 
    user_input = input("User: ")
    if(user_input in ["exit", "end"]):
        break
    else: 
        result = app.invoke({
            "messages": [HumanMessage(content=user_input)]
        }, config=config)

        print("AI: " + result["messages"][-1].content)
# Out:
# AI: Anant.

# %% [markdown]
# **When you delete the SQLite, it causes the memory to not work - "DELETE FROM checkpoints".**

# %% [markdown]
# # Human in the Loop

# %% [markdown]
# **Human-in-the-loop** workflow integrates human inputs into automated processes, and is especially useful as LLMs can generate inaccurate content or require more information occasionally:
#
# - **Reviewing tool calls**: Reviewing, editing or approving tools calls requested by the LLM before execution
# - **Validating LLM outputs**: Reviewing, editing or approving content generated by LLM
# - **Providing context**: For clarification or more details or to support multi-turn conversations

# %% [markdown]
# There are 4 key design patterns:
#
# - **Approve or reject**: Depending on the human's approval or rejection, the graph can proceed with the action or take an alternative path.
#
# <img src="images/approve-or-reject.png" width="30%" height = "30%" alt="Approve or reject">
#
#
# - **Review and edit state**: A human can review and edit the state of the graph. This is useful for correcting mistakes or updating the state with additional information.
#
# <img src="images/edit-graph-state-simple.png" width="40%" height = "40%" alt="Review and edit state">
#
#
# - **Review tool calls**: A human can review and edit the output from the LLM before proceeding. This is particularly critical in applications where the tool calls requested by the LLM may be sensitive or require human oversight.
#
# <img src="images/tool-call-review.png" width="40%" height = "40%" alt="Review tool calls">
#
#
# - **Validating human input**: To validate the input provided by the human within the graph itself (rather than on the client side).

# %% [markdown]
# Let's take an example:
#
# <img src="images/human-in-the-loop-example.png" width="20%" height = "20%" alt="Example">

# %% [markdown]
# ## Basic Working Version

# %%
from typing import TypedDict, Annotated, Literal
from langchain_core.messages import HumanMessage
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq

# %%
class State(TypedDict): 
    messages: Annotated[list, add_messages]

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
GENERATE_POST = "generate_post"
GET_REVIEW_DECISION = "get_review_decision"
POST = "post"
COLLECT_FEEDBACK = "collect_feedback"

# %%
#Add node
def generate_post(state: State): 
    return {
        "messages": [llm.invoke(state["messages"])]
    }

# %%
#Add node
def post(state: State):  
    final_post = state["messages"][-1].content  
    print("\nFinal Tweet:\n")
    print(final_post)
    print("\nTweet has been approved and is now live on Twitter!")

# %%
#Add node
def collect_feedback(state: State):  
    feedback = input("How can I improve this tweet?")
    return {
        "messages": [HumanMessage(content=feedback)]
    }

# %%
#Add conditional edge
def get_review_decision(state: State) -> Literal["post", "collect_feedback"]:  
    post_content = state["messages"][-1].content 
    
    print("\nCurrent Tweet:\n")
    print(post_content)
    print("\n")

    decision = input("Tweet? (yes/no): ")

    if decision.lower() == "yes":
        return "post"
    else:
        return "collect_feedback"

# %%
graph = StateGraph(State)

graph.add_node(GENERATE_POST, generate_post)
graph.add_node(COLLECT_FEEDBACK, collect_feedback)
graph.add_node(POST, post)

graph.set_entry_point(GENERATE_POST)

graph.add_conditional_edges(GENERATE_POST, 
                            get_review_decision)
graph.add_edge(COLLECT_FEEDBACK, GENERATE_POST)
graph.add_edge(POST, END)

app = graph.compile()

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
response = app.invoke({
    "messages": [HumanMessage(content="Write me a Tweet on TrueFoundry launching the MCP (Model Context Protocol) gateway")]
})

print("\n\n", response)
# Out:
# Current Tweet:
#
# "BREAKING: @TrueFoundry revolutionizes data management with the launch of MCP (Model Context Protocol) gateway! This game-changing tech enables seamless data exchange, boosting efficiency & innovation in industries worldwide. #MCPgateway #TrueFoundry #DataManagement"
#
#
#
# Current Tweet:
#
# "BREAKING: @TrueFoundry revolutionizes data management with the launch of MCP (Model Context Protocol) gateway! This game-changing tech enables data exchange, boosting efficiency & innovation in industries worldwide. #MCPgateway #TrueFoundry #DataManagement"
#
#
#
# Final Tweet:
#
# "BREAKING: @TrueFoundry revolutionizes data management with the launch of MCP (Model Context Protocol) gateway! This game-changing tech enables data exchange, boosting efficiency & innovation in industries worldwide. #MCPgateway #TrueFoundry #DataManagement"
#
# Tweet has been approved and is now live on Twitter!
#
#
#  {'messages': [HumanMessage(content='Write me a Tweet on TrueFoundry launching the MCP (Model Context Protocol) gateway', additional_kwargs={}, response_metadata={}, id='07449c61-c47c-4fb8-9877-f8698cef98eb'), AIMessage(content='"BREAKING: @TrueFoundry revolutionizes data management with the launch of MCP (Model Context Protocol) gateway! This game-changing tech enables seamless data exchange, boosting efficiency & innovation in industries worldwide. #MCPgateway #TrueFoundry #DataManagement"', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 52, 'total_tokens': 106, 'completion_time': 0.083528027, 'prompt_time': 0.006640527, 'queue_time': 0.051206483, 'total_time': 0.090168554}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--b4c8c5e7-9085-40b6-9bb6-66337b32b355-0', usage_metadata={'input_tokens': 52, 'output_tokens': 54, 'total_tokens': 106}), HumanMessage(content='Remove the word seamless', additional_kwargs={}, response_metadata={}, id='9f0a7885-0e94-4e76-bbc9-a94ecbf18c11'), AIMessage(content='"BREAKING: @TrueFoundry revolutionizes data management with the launch of MCP (Model Context Protocol) gateway! This game-changing tech enables data exchange, boosting efficiency & innovation in industries worldwide. #MCPgateway #TrueFoundry #DataManagement"', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 119, 'total_tokens': 172, 'completion_time': 0.045447502, 'prompt_time': 0.010833275, 'queue_time': 0.049152985, 'total_time': 0.056280777}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--3e0a1c87-5ac7-4aa0-a81a-5ee35def2c0a-0', usage_metadata={'input_tokens': 119, 'output_tokens': 53, 'total_tokens': 172})]}

# %% [markdown]
# There are several drawbacks of using `input()` function, things like it freezes your program until something's typed, works only in terminals not web apps, can handle only one user at a time, and all progress is deleted if program crashes.
#
# That's why we use the `interrupt()` method provided by LangGraph.

# %% [markdown]
# ## Using interrupt()

# %% [markdown]
# **Benefits**:
#
# - Pauses workflow and saves state to pick back up later
# - Works in web apps, APIs and other interfaces
# - Supports multiple users/sessions concurrently
# - Recovers from crashes and handles restarts
# - Lets humans take time to respond
# - Perfect for human-in-the-loop systems

# %% [markdown]
# **There are two ways for using interrupts:**
#
# 1. Interrupt in the compile step
#
# `graph = graph_builder.compile(checkpointer=checkpointer, interrupt_before = ["tools"])`
#
# 2. Interrupt function with command class
#
# `human_review = interrupt(
#     {
#         "question": "Is this correct?",
#         "tool_call": tool_call
#     }
# )`
#
# `if review_action == "continue":
#     return Command(goto = "run_tool")`

# %% [markdown]
# **The Command class in LangGraph allows us to create edgeless workflows**.

# %% [markdown]
# ### Basic Examples for Understanding

# %% [markdown]
# #### Example 1

# %% [markdown]
# Approve or reject use case with the second way of using `interrupt()` method

# %%
from langgraph.graph import StateGraph, START, END
from langgraph.types import Command, interrupt
from typing import TypedDict
from langgraph.checkpoint.memory import MemorySaver

# %%
memory = MemorySaver()

# %%
class State(TypedDict):
    value: str

# %%
def node_a(state: State): 
    print("Node A")
    return Command(
        goto="node_b", 
        update={
            "value": state["value"] + "a"
        }
    )

# %%
def node_b(state: State): 
    print("Node B")

    human_response = interrupt("Do you want to go to C or D? Type C/D")

    print("Human Review Values: ", human_response)
    
    if(human_response == "C"): 
        return Command(
            goto="node_c", 
            update={
                "value": state["value"] + "b"
            }
        ) 
    elif(human_response == "D"): 
        return Command(
            goto="node_d", 
            update={
                "value": state["value"] + "b"
            }
        )

# %%
def node_c(state: State): 
    print("Node C")
    return Command(
        goto=END, 
        update={
            "value": state["value"] + "c"
        }
    )

# %%
def node_d(state: State): 
    print("Node D")
    return Command(
        goto=END, 
        update={
            "value": state["value"] + "d"
        }
)

# %%
graph = StateGraph(State)

graph.add_node("node_a", node_a)
graph.add_node("node_b", node_b)
graph.add_node("node_c", node_c)
graph.add_node("node_d", node_d)

graph.set_entry_point("node_a") 

app = graph.compile(checkpointer=memory)

# %%
config = {"configurable": {"thread_id": "1"}}

# %%
initialState = {
    "value": ""
}

# %%
first_result = app.invoke(initialState, config, stream_mode="updates")
first_result
# Out:
# Node A
# Node B
# [{'node_a': {'value': 'a'}},
#  {'__interrupt__': (Interrupt(value='Do you want to go to C or D? Type C/D', resumable=True, ns=['node_b:35de1c4e-c86b-5895-0474-4d18844c263c']),)}]

# %%
app.get_state(config)
# Out:
# StateSnapshot(values={'value': 'a'}, next=('node_b',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0924cd-13ac-6968-8001-a5f8dffe9117'}}, metadata={'source': 'loop', 'writes': {'node_a': {'value': 'a'}}, 'step': 1, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-15T15:58:27.394591+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0924cd-13a7-6e04-8000-d09d5d34f51c'}}, tasks=(PregelTask(id='35de1c4e-c86b-5895-0474-4d18844c263c', name='node_b', path=('__pregel_pull', 'node_b'), error=None, interrupts=(Interrupt(value='Do you want to go to C or D? Type C/D', resumable=True, ns=['node_b:35de1c4e-c86b-5895-0474-4d18844c263c']),), state=None, result=None),), interrupts=(Interrupt(value='Do you want to go to C or D? Type C/D', resumable=True, ns=['node_b:35de1c4e-c86b-5895-0474-4d18844c263c']),))

# %%
#This gives information about the next node to go to, since it is checkpointed
print(app.get_state(config).next)
# Out:
# ('node_b',)

# %%
#I want to go to C
second_result = app.invoke(Command(resume="C"), config=config, stream_mode="updates")
second_result
# Out:
# Node B
# Human Review Values:  C
# Node C
# [{'node_b': {'value': 'ab'}}, {'node_c': {'value': 'abc'}}]

# %%
#Running this again, we'll not get anything because the graph has already executed - there's no interrupt method. Either change the thread id and start from scratch / or use time travel
second_result = app.invoke(Command(resume="C"), config=config, stream_mode="updates")
second_result
# Out:
# []

# %% [markdown]
# #### Example 2

# %% [markdown]
# Reviewing tool calls and using the first way of using `interrupt` method to check before the tool is actually executed.

# %%
from IPython.display import Image, display
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import AIMessage, HumanMessage
from dotenv import load_dotenv
from langchain_tavily import TavilySearch
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.checkpoint.memory import InMemorySaver

# %%
memory = InMemorySaver()

# %%
class SimpleChatState(TypedDict):
    messages: Annotated[list, add_messages]

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
search_tool = TavilySearch(max_results=2)
tools = [search_tool]

# %%
llm_with_tools = llm.bind_tools(tools=tools)

# %%
def tool_enabled_chatbot(state: SimpleChatState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

# %% [markdown]
# We use the [built-in `ToolNode`](https://langchain-ai.github.io/langgraph/reference/prebuilt/?h=tools+condition#toolnode) and simply pass a list of our tools to initialize it.

# %%
tool_node = ToolNode(tools=tools)

# %% [markdown]
# We can also use the [built-in `tools_condition`](https://langchain-ai.github.io/langgraph/reference/prebuilt/?h=tools+condition#tools_condition) as our conditional edge. Here - we first define a custom router for explanation, but show a streamlined manner just using `tools_condition`.

# %%
#Using tools_condition
graph = StateGraph(SimpleChatState)

graph.add_node("chatbot", tool_enabled_chatbot)
graph.add_node("tools", tool_node)
graph.set_entry_point("chatbot")

graph.add_conditional_edges("chatbot", 
                            tools_condition)
graph.add_edge("tools", "chatbot")

# %%
#This is where there's a change | there's also an interrupt_after that exits the graph after the tool node is executed (another use case)
app = graph.compile(checkpointer=memory, interrupt_before=["tools"])

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
config = {"configurable": {
    "thread_id": 1
}}

# %%
#We'll not use invoke and use stream instead -> invoke returns a value only when the graph has executed, either because of interrupt method or the graph has completed | stream emits events after every single node
events = app.stream({
    "messages": [HumanMessage(content="What is the current weather in Indore?")]
}, config=config, stream_mode="values")

for event in events:
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the current weather in Indore?
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (6prbd8tqv)
#  Call ID: 6prbd8tqv
#   Args:
#     query: current weather in Indore
#     topic: news

# %%
#This will be tools, because the tool node is responsible for executing the tool call
snapshot = app.get_state(config=config)
snapshot.next
# Out:
# ('tools',)

# %%
#Executes Tavily search tool
events = app.stream(None, config, stream_mode="values")
for event in events:
    event["messages"][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (68hwhd2wn)
#  Call ID: 68hwhd2wn
#   Args:
#     query: Indore current weather
#     topic: news
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "Indore current weather", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.skynews.com.au/australia-news/weather/showers-likely-to-ease-in-nations-drenched-southwest-corner-after-wet-and-chilly-weekend-for-west-coast/news-story/5d5b6f94988edc1ffbffb0f9e43ea9d8", "title": "Showers likely to ease in drenched and chilly south-west - Sky News Australia", "score": 0.1591785, "published_date": "Sun, 07 Sep 2025 19:18:43 GMT", "content": "Skies are expected to gradually clear in the country’s south-west corner following a wet and chilly weekend for much of the west coast. Examining the forecast for the start of the week, Sky News Weather Presenter Julia Seymour said a cold front, which had brought wet and windy weather with it, would continue to push across the country’s south-east into Monday. Further ahead, though, the BOM has forecast just a five percent chance of rain for the city on Tuesday and a maximum temperature of 18 degrees, with sunny conditions looking likely for WA's capital later in the week before wet weather is expected to return by the weekend.", "raw_content": null}, {"url": "https://kfgo.com/2025/09/09/police-officer-suffers-self-inflicted-gunshot-wound-after-several-hours-of-negotiations/", "title": "Police officer suffers self-inflicted gunshot wound after several hours of negotiations - The Mighty 790 KFGO", "score": 0.096441865, "published_date": "Wed, 10 Sep 2025 02:04:33 GMT", "content": "* WEATHER (KFGO KZZY) – Devils Lake police say an off-duty officer shot himself after an hours-long standoff at a home in Devils Lake. Police Chief Jason Toso says officers responded to a home late Monday night after a 911 hang-up call. A judge approved a search warrant for the home. Toso says the officer was taken to a hospital. ## Comments You must be logged in to post a comment. 1h agoUS health officials compiling examples of COVID vaccine harm during pregnancy, WSJ reports 2h agoDollar treads water ahead of inflation reports; US rate cut bets intact 52m agoSlim iPhone Air could be a design win for Apple, analysts say 1h ago ## Current Weather » ### Fargo, ND Fargo, ND, USA", "raw_content": null}], "response_time": 0.35, "request_id": "a93781ac-4569-43ff-80d2-47d181fcff1d"}
# ================================== Ai Message ==================================
#
# It seems like the function call did not return the current weather in Indore. Let's try again with a different function call.
# Tool Calls:
#   tavily_search (cqcx0c0p6)
#  Call ID: cqcx0c0p6
#   Args:
#     query: Indore weather today
#     topic: general

# %% [markdown]
# #### Example 3 - Coming back to our main example in this section

# %% [markdown]
# Multi-turn conversations and reuse the Tweet creation example

# %%
from langgraph.graph import StateGraph, START, END, add_messages
from langgraph.types import Command, interrupt
from typing import TypedDict, Annotated, List
from langgraph.checkpoint.memory import MemorySaver
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
import uuid

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
class State(TypedDict): 
    tweet_topic: str #in the beginning
    generated_post: Annotated[List[str], add_messages] #every time the model created the post
    human_feedback: Annotated[List[str], add_messages] #every time there's a feedback

# %%
def model(state: State): 
    """ Here, we're using the LLM to generate a Twitter post with human feedback incorporated """

    print("[model] Generating content")
    tweet_topic = state["tweet_topic"]
    feedback = state["human_feedback"] if "human_feedback" in state else ["No Feedback yet"]

    # Here, we define the prompt 

    prompt = f"""

        Tweet Topic: {tweet_topic}
        Human Feedback: {feedback[-1] if feedback else "No feedback yet"}

        Generate a structured and well-written Twitter post based on the given topic.

        Consider previous human feedback to refine the reponse. 
    """

    response = llm.invoke([
        SystemMessage(content="You are an expert Twitter content writer"), 
        HumanMessage(content=prompt)
    ])

    generated_twitter_post = response.content

    print(f"[model_node] Generated post:\n{generated_twitter_post}\n")

    return {
       "generated_post": [AIMessage(content=generated_twitter_post)] , 
       "human_feedback": feedback
    }

# %%
def human_node(state: State): 
    """Human Intervention node - loops back to model unless input is done"""

    print("\n [human_node] awaiting human feedback...")

    generated_post = state["generated_post"]

    # Interrupt to get user feedback

    user_feedback = interrupt(
        {
            "generated_post": generated_post, 
            "message": "Provide feedback or type 'done' to finish"
        }
    )

    print(f"[human_node] Received human feedback: {user_feedback}")

    # If user types "done", transition to END node
    if user_feedback.lower() == "done": 
        return Command(update={"human_feedback": state["human_feedback"] + ["Finalised"]}, goto="end_node")

    # Otherwise, update feedback and return to model for re-generation
    return Command(update={"human_feedback": state["human_feedback"] + [user_feedback]}, goto="model")

# %%
def end_node(state: State): 
    """ Final node """
    print("\n[end_node] Process finished")
    print("Final Generated Post:", state["generated_post"][-1])
    print("Final Human Feedback", state["human_feedback"])
    return {"generated_post": state["generated_post"], "human_feedback": state["human_feedback"]}

# %%
# Buiding the Graph

graph = StateGraph(State)
graph.add_node("model", model)
graph.add_node("human_node", human_node)
graph.add_node("end_node", end_node)

# %%
# Define the flow
graph.set_entry_point("model")
graph.add_edge("model", "human_node")
graph.add_edge("human_node", "end_node")
graph.set_finish_point("end_node")

# %%
# Enable Interrupt mechanism
checkpointer = MemorySaver()
app = graph.compile(checkpointer=checkpointer)

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
thread_config = {"configurable": {
    "thread_id": uuid.uuid4()
}}

# %%
tweet_topic = input("Enter your Tweet topic: ")
initial_state = {
    "tweet_topic": tweet_topic, 
    "generated_post": [], 
    "human_feedback": []
}

# %%
for chunk in app.stream(initial_state, config=thread_config):
    for node_id, value in chunk.items():
        #  If we reach an interrupt, continuously ask for human feedback

        if(node_id == "__interrupt__"):
            while True: 
                user_feedback = input("Provide feedback (or type 'done' when finished): ")

                # Resume the graph execution with the user's feedback
                app.invoke(Command(resume=user_feedback), config=thread_config)

                # Exit loop if user says done
                if user_feedback.lower() == "done":
                    break
# Out:
# [model] Generating content
# [model_node] Generated post:
# Since there is no previous human feedback, I'll create a general response to the topic "AI Gateway".
#
# **Tweet 1: Introduction**
# Introducing the AI Gateway: Unlocking Seamless Integration between Humans & Machines!
#
# Imagine a world where technology understands you, anticipates your needs, and elevates your experience. The AI Gateway is revolutionizing the way we interact with AI, making it more intuitive, efficient, and human-centric.
#
# **Tweet 2: Benefits**
# Boost productivity with AI-driven workflows
# Enhance customer experience with personalized interactions
# Unlock new insights with data-driven decision-making
#
# The AI Gateway is the key to unlocking a future where humans and machines collaborate seamlessly. Are you ready to experience the future of AI?
#
# **Tweet 3: Call-to-Action**
# Want to learn more about the AI Gateway and how it can transform your business or personal life? Stay tuned for updates, expert insights, and exclusive content!
#
# #AIGateway #ArtificialIntelligence #FutureOfWork #TechInnovation
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: Make it super technical and less than 15 words
#
# [end_node] Process finished
# Final Generated Post: content='Since there is no previous human feedback, I\'ll create a general response to the topic "AI Gateway".\n\n**Tweet 1: Introduction**\nIntroducing the AI Gateway: Unlocking Seamless Integration between Humans & Machines!\n\nImagine a world where technology understands you, anticipates your needs, and elevates your experience. The AI Gateway is revolutionizing the way we interact with AI, making it more intuitive, efficient, and human-centric.\n\n**Tweet 2: Benefits**\nBoost productivity with AI-driven workflows\nEnhance customer experience with personalized interactions\nUnlock new insights with data-driven decision-making\n\nThe AI Gateway is the key to unlocking a future where humans and machines collaborate seamlessly. Are you ready to experience the future of AI?\n\n**Tweet 3: Call-to-Action**\nWant to learn more about the AI Gateway and how it can transform your business or personal life? Stay tuned for updates, expert insights, and exclusive content!\n\n#AIGateway #ArtificialIntelligence #FutureOfWork #TechInnovation' additional_kwargs={} response_metadata={} id='e2afcc28-fb27-452a-a3ca-e957664daa41'
# Final Human Feedback [HumanMessage(content='Make it super technical and less than 15 words', additional_kwargs={}, response_metadata={}, id='f352515f-9027-4b2b-9876-7e0d3131259f')]
# [model] Generating content
# [model_node] Generated post:
# Here's a revised Twitter post based on the provided topic and feedback:
#
# "Introducing AI Gateway: A scalable, containerized API gateway leveraging Kubernetes & gRPC for real-time AI data processing #AIGateway #AIEngineering"
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: done
#
# [end_node] Process finished
# Final Generated Post: content='Here\'s a revised Twitter post based on the provided topic and feedback:\n\n"Introducing AI Gateway: A scalable, containerized API gateway leveraging Kubernetes & gRPC for real-time AI data processing #AIGateway #AIEngineering"' additional_kwargs={} response_metadata={} id='2f9b0688-b5c5-4b30-bf3e-352e34439200'
# Final Human Feedback [HumanMessage(content='Make it super technical and less than 15 words', additional_kwargs={}, response_metadata={}, id='f352515f-9027-4b2b-9876-7e0d3131259f'), HumanMessage(content='Finalised', additional_kwargs={}, response_metadata={}, id='0f2ba382-23ee-4144-9834-e3075d307ffe')]

# %% [markdown]
# # Streaming

# %%
from IPython.display import Image, display
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import AIMessage, HumanMessage
from dotenv import load_dotenv
from langchain_tavily import TavilySearch
from langgraph.prebuilt import ToolNode, tools_condition

# %%
class SimpleChatState(TypedDict):
    messages: Annotated[list, add_messages]

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
search_tool = TavilySearch(max_results=2)
tools = [search_tool]

# %%
llm_with_tools = llm.bind_tools(tools=tools)

# %%
def tool_enabled_chatbot(state: SimpleChatState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

# %% [markdown]
# We use the [built-in `ToolNode`](https://langchain-ai.github.io/langgraph/reference/prebuilt/?h=tools+condition#toolnode) and simply pass a list of our tools to initialize it.

# %%
tool_node = ToolNode(tools=tools)

# %% [markdown]
# We can also use the [built-in `tools_condition`](https://langchain-ai.github.io/langgraph/reference/prebuilt/?h=tools+condition#tools_condition) as our conditional edge. Here - we first define a custom router for explanation, but show a streamlined manner just using `tools_condition`.

# %%
#From scratch - else use tools_condition
def tools_router(state: SimpleChatState):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tools"
    else: 
        return "end"

# %%
#Using tools_condition
graph = StateGraph(SimpleChatState)

graph.add_node("chatbot", tool_enabled_chatbot)
graph.add_node("tools", tool_node)
graph.set_entry_point("chatbot")

graph.add_conditional_edges("chatbot", 
                            tools_condition)
graph.add_edge("tools", "chatbot")

app = graph.compile()

# %%
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
## From earlier --> 
# result = app.invoke({
#     "messages": [HumanMessage(content=user_input)]
# })

# print("AI: " + result["messages"][-1].content + "\n")

# %%
input = {
    "messages": ["What's the current weather in Indore?"]
}

#Stream mode to values means that after execution of every node, an event will be emitted showing us the entire state at that point
events = app.stream(input=input, stream_mode="values")

#For every event from the generator, we'll see the event
for event in events: 
    print(event["messages"], "\n\n")
# Out:
# [HumanMessage(content="What's the current weather in Indore?", additional_kwargs={}, response_metadata={}, id='dfefa913-f37a-4580-b295-66fb2d20225c')]
#
#
# [HumanMessage(content="What's the current weather in Indore?", additional_kwargs={}, response_metadata={}, id='dfefa913-f37a-4580-b295-66fb2d20225c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6y45g3vb9', 'function': {'arguments': '{"end_date":null,"query":"Indore current weather","start_date":null,"topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 1795, 'total_tokens': 1831, 'completion_time': 0.04838267, 'prompt_time': 0.12097559, 'queue_time': 0.052188959, 'total_time': 0.16935826}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--807c2d6c-dd5d-47b8-bf46-575f23ebf47d-0', tool_calls=[{'name': 'tavily_search', 'args': {'end_date': None, 'query': 'Indore current weather', 'start_date': None, 'topic': 'news'}, 'id': '6y45g3vb9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1795, 'output_tokens': 36, 'total_tokens': 1831})]
#
#
# [HumanMessage(content="What's the current weather in Indore?", additional_kwargs={}, response_metadata={}, id='dfefa913-f37a-4580-b295-66fb2d20225c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6y45g3vb9', 'function': {'arguments': '{"end_date":null,"query":"Indore current weather","start_date":null,"topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 1795, 'total_tokens': 1831, 'completion_time': 0.04838267, 'prompt_time': 0.12097559, 'queue_time': 0.052188959, 'total_time': 0.16935826}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--807c2d6c-dd5d-47b8-bf46-575f23ebf47d-0', tool_calls=[{'name': 'tavily_search', 'args': {'end_date': None, 'query': 'Indore current weather', 'start_date': None, 'topic': 'news'}, 'id': '6y45g3vb9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1795, 'output_tokens': 36, 'total_tokens': 1831}), ToolMessage(content='{"query": "Indore current weather", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.washingtonpost.com/weather/2025/09/10/dc-weather-live-updates-wednesday-shower-beautiful-weekend/", "title": "CWG Live updates: Occasional light showers or sprinkles today, then back to beautiful - The Washington Post", "score": 0.098503634, "published_date": "Wed, 10 Sep 2025 11:37:07 GMT", "content": "# CWG Live updates Occasional light showers or sprinkles today, then back to beautiful Highs in the upper 70s to low 80s tomorrow through Saturday, then low to mid-80s Sunday and Monday. Pinned post Dan Stillman **Today (Wednesday):** Mostly cloudy with some occasional light showers or sprinkles throughout the day as low pressure spins off the coast. High pressure dominates **Friday and Saturday**, keeping skies partly to mostly sunny with highs in the upper 70s to low 80s and comfortable humidity (dew points in the 50s). CWG Live updates: Cloudier and damp into Wednesday, then nice weather returns CWG Live updates: The nicest week of the year is ahead CWG Live updates: Cooler, drier and clearer tonight; nice week ahead!", "raw_content": null}, {"url": "https://kfgo.com/2025/09/09/police-officer-suffers-self-inflicted-gunshot-wound-after-several-hours-of-negotiations/", "title": "Police officer suffers self-inflicted gunshot wound after several hours of negotiations - The Mighty 790 KFGO", "score": 0.096441865, "published_date": "Wed, 10 Sep 2025 02:04:33 GMT", "content": "* WEATHER (KFGO KZZY) – Devils Lake police say an off-duty officer shot himself after an hours-long standoff at a home in Devils Lake. Police Chief Jason Toso says officers responded to a home late Monday night after a 911 hang-up call. A judge approved a search warrant for the home. Toso says the officer was taken to a hospital. ## Comments You must be logged in to post a comment. 1h agoUS health officials compiling examples of COVID vaccine harm during pregnancy, WSJ reports 2h agoDollar treads water ahead of inflation reports; US rate cut bets intact 52m agoSlim iPhone Air could be a design win for Apple, analysts say 1h ago ## Current Weather » ### Fargo, ND Fargo, ND, USA", "raw_content": null}], "response_time": 0.69, "request_id": "b082628f-a522-4cd4-96f0-792d5ea42f74"}', name='tavily_search', id='04cb3301-e4e4-4287-a66d-fb5da89b3496', tool_call_id='6y45g3vb9')]
#
#
# [HumanMessage(content="What's the current weather in Indore?", additional_kwargs={}, response_metadata={}, id='dfefa913-f37a-4580-b295-66fb2d20225c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6y45g3vb9', 'function': {'arguments': '{"end_date":null,"query":"Indore current weather","start_date":null,"topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 1795, 'total_tokens': 1831, 'completion_time': 0.04838267, 'prompt_time': 0.12097559, 'queue_time': 0.052188959, 'total_time': 0.16935826}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--807c2d6c-dd5d-47b8-bf46-575f23ebf47d-0', tool_calls=[{'name': 'tavily_search', 'args': {'end_date': None, 'query': 'Indore current weather', 'start_date': None, 'topic': 'news'}, 'id': '6y45g3vb9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1795, 'output_tokens': 36, 'total_tokens': 1831}), ToolMessage(content='{"query": "Indore current weather", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.washingtonpost.com/weather/2025/09/10/dc-weather-live-updates-wednesday-shower-beautiful-weekend/", "title": "CWG Live updates: Occasional light showers or sprinkles today, then back to beautiful - The Washington Post", "score": 0.098503634, "published_date": "Wed, 10 Sep 2025 11:37:07 GMT", "content": "# CWG Live updates Occasional light showers or sprinkles today, then back to beautiful Highs in the upper 70s to low 80s tomorrow through Saturday, then low to mid-80s Sunday and Monday. Pinned post Dan Stillman **Today (Wednesday):** Mostly cloudy with some occasional light showers or sprinkles throughout the day as low pressure spins off the coast. High pressure dominates **Friday and Saturday**, keeping skies partly to mostly sunny with highs in the upper 70s to low 80s and comfortable humidity (dew points in the 50s). CWG Live updates: Cloudier and damp into Wednesday, then nice weather returns CWG Live updates: The nicest week of the year is ahead CWG Live updates: Cooler, drier and clearer tonight; nice week ahead!", "raw_content": null}, {"url": "https://kfgo.com/2025/09/09/police-officer-suffers-self-inflicted-gunshot-wound-after-several-hours-of-negotiations/", "title": "Police officer suffers self-inflicted gunshot wound after several hours of negotiations - The Mighty 790 KFGO", "score": 0.096441865, "published_date": "Wed, 10 Sep 2025 02:04:33 GMT", "content": "* WEATHER (KFGO KZZY) – Devils Lake police say an off-duty officer shot himself after an hours-long standoff at a home in Devils Lake. Police Chief Jason Toso says officers responded to a home late Monday night after a 911 hang-up call. A judge approved a search warrant for the home. Toso says the officer was taken to a hospital. ## Comments You must be logged in to post a comment. 1h agoUS health officials compiling examples of COVID vaccine harm during pregnancy, WSJ reports 2h agoDollar treads water ahead of inflation reports; US rate cut bets intact 52m agoSlim iPhone Air could be a design win for Apple, analysts say 1h ago ## Current Weather » ### Fargo, ND Fargo, ND, USA", "raw_content": null}], "response_time": 0.69, "request_id": "b082628f-a522-4cd4-96f0-792d5ea42f74"}', name='tavily_search', id='04cb3301-e4e4-4287-a66d-fb5da89b3496', tool_call_id='6y45g3vb9'), AIMessage(content='The function call returned an incorrect response. The function call should return the current weather in Indore. Let me try again.\n\n', additional_kwargs={'tool_calls': [{'id': 'cfnz23cd6', 'function': {'arguments': '{"end_date":null,"query":"Indore weather today","start_date":null,"topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 2443, 'total_tokens': 2505, 'completion_time': 0.116 ...
#
#
# [HumanMessage(content="What's the current weather in Indore?", additional_kwargs={}, response_metadata={}, id='dfefa913-f37a-4580-b295-66fb2d20225c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6y45g3vb9', 'function': {'arguments': '{"end_date":null,"query":"Indore current weather","start_date":null,"topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 1795, 'total_tokens': 1831, 'completion_time': 0.04838267, 'prompt_time': 0.12097559, 'queue_time': 0.052188959, 'total_time': 0.16935826}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--807c2d6c-dd5d-47b8-bf46-575f23ebf47d-0', tool_calls=[{'name': 'tavily_search', 'args': {'end_date': None, 'query': 'Indore current weather', 'start_date': None, 'topic': 'news'}, 'id': '6y45g3vb9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1795, 'output_tokens': 36, 'total_tokens': 1831}), ToolMessage(content='{"query": "Indore current weather", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.washingtonpost.com/weather/2025/09/10/dc-weather-live-updates-wednesday-shower-beautiful-weekend/", "title": "CWG Live updates: Occasional light showers or sprinkles today, then back to beautiful - The Washington Post", "score": 0.098503634, "published_date": "Wed, 10 Sep 2025 11:37:07 GMT", "content": "# CWG Live updates Occasional light showers or sprinkles today, then back to beautiful Highs in the upper 70s to low 80s tomorrow through Saturday, then low to mid-80s Sunday and Monday. Pinned post Dan Stillman **Today (Wednesday):** Mostly cloudy with some occasional light showers or sprinkles throughout the day as low pressure spins off the coast. High pressure dominates **Friday and Saturday**, keeping skies partly to mostly sunny with highs in the upper 70s to low 80s and comfortable humidity (dew points in the 50s). CWG Live updates: Cloudier and damp into Wednesday, then nice weather returns CWG Live updates: The nicest week of the year is ahead CWG Live updates: Cooler, drier and clearer tonight; nice week ahead!", "raw_content": null}, {"url": "https://kfgo.com/2025/09/09/police-officer-suffers-self-inflicted-gunshot-wound-after-several-hours-of-negotiations/", "title": "Police officer suffers self-inflicted gunshot wound after several hours of negotiations - The Mighty 790 KFGO", "score": 0.096441865, "published_date": "Wed, 10 Sep 2025 02:04:33 GMT", "content": "* WEATHER (KFGO KZZY) – Devils Lake police say an off-duty officer shot himself after an hours-long standoff at a home in Devils Lake. Police Chief Jason Toso says officers responded to a home late Monday night after a 911 hang-up call. A judge approved a search warrant for the home. Toso says the officer was taken to a hospital. ## Comments You must be logged in to post a comment. 1h agoUS health officials compiling examples of COVID vaccine harm during pregnancy, WSJ reports 2h agoDollar treads water ahead of inflation reports; US rate cut bets intact 52m agoSlim iPhone Air could be a design win for Apple, analysts say 1h ago ## Current Weather » ### Fargo, ND Fargo, ND, USA", "raw_content": null}], "response_time": 0.69, "request_id": "b082628f-a522-4cd4-96f0-792d5ea42f74"}', name='tavily_search', id='04cb3301-e4e4-4287-a66d-fb5da89b3496', tool_call_id='6y45g3vb9'), AIMessage(content='The function call returned an incorrect response. The function call should return the current weather in Indore. Let me try again.\n\n', additional_kwargs={'tool_calls': [{'id': 'cfnz23cd6', 'function': {'arguments': '{"end_date":null,"query":"Indore weather today","start_date":null,"topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 2443, 'total_tokens': 2505, 'completion_time': 0.116 ...
#
#
# [HumanMessage(content="What's the current weather in Indore?", additional_kwargs={}, response_metadata={}, id='dfefa913-f37a-4580-b295-66fb2d20225c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6y45g3vb9', 'function': {'arguments': '{"end_date":null,"query":"Indore current weather","start_date":null,"topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 1795, 'total_tokens': 1831, 'completion_time': 0.04838267, 'prompt_time': 0.12097559, 'queue_time': 0.052188959, 'total_time': 0.16935826}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--807c2d6c-dd5d-47b8-bf46-575f23ebf47d-0', tool_calls=[{'name': 'tavily_search', 'args': {'end_date': None, 'query': 'Indore current weather', 'start_date': None, 'topic': 'news'}, 'id': '6y45g3vb9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1795, 'output_tokens': 36, 'total_tokens': 1831}), ToolMessage(content='{"query": "Indore current weather", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.washingtonpost.com/weather/2025/09/10/dc-weather-live-updates-wednesday-shower-beautiful-weekend/", "title": "CWG Live updates: Occasional light showers or sprinkles today, then back to beautiful - The Washington Post", "score": 0.098503634, "published_date": "Wed, 10 Sep 2025 11:37:07 GMT", "content": "# CWG Live updates Occasional light showers or sprinkles today, then back to beautiful Highs in the upper 70s to low 80s tomorrow through Saturday, then low to mid-80s Sunday and Monday. Pinned post Dan Stillman **Today (Wednesday):** Mostly cloudy with some occasional light showers or sprinkles throughout the day as low pressure spins off the coast. High pressure dominates **Friday and Saturday**, keeping skies partly to mostly sunny with highs in the upper 70s to low 80s and comfortable humidity (dew points in the 50s). CWG Live updates: Cloudier and damp into Wednesday, then nice weather returns CWG Live updates: The nicest week of the year is ahead CWG Live updates: Cooler, drier and clearer tonight; nice week ahead!", "raw_content": null}, {"url": "https://kfgo.com/2025/09/09/police-officer-suffers-self-inflicted-gunshot-wound-after-several-hours-of-negotiations/", "title": "Police officer suffers self-inflicted gunshot wound after several hours of negotiations - The Mighty 790 KFGO", "score": 0.096441865, "published_date": "Wed, 10 Sep 2025 02:04:33 GMT", "content": "* WEATHER (KFGO KZZY) – Devils Lake police say an off-duty officer shot himself after an hours-long standoff at a home in Devils Lake. Police Chief Jason Toso says officers responded to a home late Monday night after a 911 hang-up call. A judge approved a search warrant for the home. Toso says the officer was taken to a hospital. ## Comments You must be logged in to post a comment. 1h agoUS health officials compiling examples of COVID vaccine harm during pregnancy, WSJ reports 2h agoDollar treads water ahead of inflation reports; US rate cut bets intact 52m agoSlim iPhone Air could be a design win for Apple, analysts say 1h ago ## Current Weather » ### Fargo, ND Fargo, ND, USA", "raw_content": null}], "response_time": 0.69, "request_id": "b082628f-a522-4cd4-96f0-792d5ea42f74"}', name='tavily_search', id='04cb3301-e4e4-4287-a66d-fb5da89b3496', tool_call_id='6y45g3vb9'), AIMessage(content='The function call returned an incorrect response. The function call should return the current weather in Indore. Let me try again.\n\n', additional_kwargs={'tool_calls': [{'id': 'cfnz23cd6', 'function': {'arguments': '{"end_date":null,"query":"Indore weather today","start_date":null,"topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 2443, 'total_tokens': 2505, 'completion_time': 0.116 ...

# %%
input = {
    "messages": ["What's the current weather in Bangalore?"]
}

#Updates gives the new item that has been added to the list, and which node did the change
events = app.stream(input=input, stream_mode="updates")

for event in events: 
    print(event, "\n\n")
# Out:
# {'chatbot': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'm7t43kh57', 'function': {'arguments': '{"query":"Bangalore current weather","search_depth":"basic","topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 1794, 'total_tokens': 1826, 'completion_time': 0.048019892, 'prompt_time': 0.1214803, 'queue_time': 0.05092368, 'total_time': 0.169500192}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--af0991e3-7764-4c12-91e2-dc9a971f3b32-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'Bangalore current weather', 'search_depth': 'basic', 'topic': 'news'}, 'id': 'm7t43kh57', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1794, 'output_tokens': 32, 'total_tokens': 1826})]}}
#
#
# {'tools': {'messages': [ToolMessage(content='{"query": "Bangalore current weather", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://kfgo.com/2025/09/09/police-officer-suffers-self-inflicted-gunshot-wound-after-several-hours-of-negotiations/", "title": "Police officer suffers self-inflicted gunshot wound after several hours of negotiations - The Mighty 790 KFGO", "score": 0.06827003, "published_date": "Wed, 10 Sep 2025 02:04:33 GMT", "content": "* WEATHER (KFGO KZZY) – Devils Lake police say an off-duty officer shot himself after an hours-long standoff at a home in Devils Lake. Police Chief Jason Toso says officers responded to a home late Monday night after a 911 hang-up call. A judge approved a search warrant for the home. Toso says the officer was taken to a hospital. ## Comments You must be logged in to post a comment. 1h agoUS health officials compiling examples of COVID vaccine harm during pregnancy, WSJ reports 2h agoDollar treads water ahead of inflation reports; US rate cut bets intact 52m agoSlim iPhone Air could be a design win for Apple, analysts say 1h ago ## Current Weather » ### Fargo, ND Fargo, ND, USA", "raw_content": null}, {"url": "https://www.wtva.com/video/first-responders-oxford-police-hosting-women-s-self-defense-class/video_752e5f5a-6659-52f1-922c-9dede72356a6.html", "title": "First Responders: Oxford police hosting women’s self-defense class - WTVA", "score": 0.067307346, "published_date": "Tue, 09 Sep 2025 21:40:00 GMT", "content": "You have permission to edit this video. * **Email Alerts** * Sign Up For WTVA Email Alerts * Download News, Weather & TV Apps # First Responders: Oxford police hosting women’s self-defense class * Email Video Player is loading. Current Time\xa00:00 * descriptions off, selected * captions off, selected * default, selected This is a modal window. Beginning of dialog window. End of dialog window. The Oxford Police Department is hosting a self-defense class for women on Sept. ### Top Videos * Email Video Player is loading. Current Time\xa00:00 * descriptions off, selected * captions off, selected This is a modal window. Beginning of dialog window. End of dialog window. Currently in Tupelo 82°F 85°F / 62°F 80°F 76°F 73°F", "raw_content": null}], "response_time": 0.33, "request_id": "78ed982c-4d37-4518-86e2-d08ec3c5b3ec"}', name='tavily_search', id='7545eeab-d6d2-4e21-b7cf-252574b0d562', tool_call_id='m7t43kh57')]}}
#
#
# {'chatbot': {'messages': [AIMessage(content="The current results are about other topics as the search query was too broad. Let's try a more specific query to get accurate results.\n\n", additional_kwargs={'tool_calls': [{'id': 'p0qnaxjrm', 'function': {'arguments': '{"query":"Bangalore weather today","search_depth":"advanced","topic":"news"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 2454, 'total_tokens': 2513, 'completion_time': 0.115152091, 'prompt_time': 0.16252514, 'queue_time': 0.053802859, 'total_time': 0.277677231}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--d02d6949-433b-4ad4-82d3-a2b748c6d6e9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'Bangalore weather today', 'search_depth': 'advanced', 'topic': 'news'}, 'id': 'p0qnaxjrm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2454, 'output_tokens': 59, 'total_tokens': 2513})]}}
#
#
# {'tools': {'messages': [ToolMessage(content='{"query": "Bangalore weather today", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.washingtonpost.com/weather/2025/09/13/dc-weather-live-updates-weekend-forecast/", "title": "CWG Live updates: Late-summer warmth in town for the weekend - The Washington Post", "score": 0.16035835, "published_date": "Sat, 13 Sep 2025 18:41:59 GMT", "content": "Today’s daily digit — 8/10: Teetering near or into above average temperature territory during the nicest time of year. | 🤚 Your call?\\n\\n  The digit is a somewhat subjective rating of the day’s weather, on a 0-to-10 scale.\\n\\n  Forecast in detail\\n\\n  Today (Saturday): Clouds are few and humidity is on the low side with dew points in the mid-50s or so. Highs range from near 80 in the cooler spots to mid-80s in the city. Light winds blow out of the south. Confidence: High 😎 Nice Day! [...] Tomorrow night: Given a slow rise in humidity, temperatures may be up a degree or two from tonight. Near 60 to mid-60s should still do it many spots. Partly cloudy overall, but maybe a patch of fog by the predawn. Confidence: Medium-High\\n\\n  A look ahead\\n\\n  On Monday we should see somewhat higher humidity and a bit more cloud cover compared to the weekend. This won’t impact temperatures too much. Looks like another round of mainly low to mid-80s highs. Confidence: Medium [...] Tonight: Mostly clear skies rule. Lows reach the upper 50s in cooler outer suburbs, with many locations in and around the Beltway ranging near 60 to the mid-60s. Confidence: High\\n\\n  Tomorrow (Sunday): Still mostly sunny, with just a few midday clouds popping up.Probably a touch warmer than today — highs about 81 to 87 areawide. Confidence: High", "raw_content": null}, {"url": "https://www.washingtonpost.com/weather/2025/09/12/dc-weather-live-updates-warmer-weekend/", "title": "CWG Live updates: Nice for days to come, plus a warming trend into early week - The Washington Post", "score": 0.14954409, "published_date": "Fri, 12 Sep 2025 11:38:56 GMT", "content": "Sunday: Mainly bright but some clouds are possible late day, when we could even see a brief, stray shower. Very low chance as it looks now. Highs may top out within a few degrees of 85. Confidence: Medium\\n\\nA look ahead\\n\\nSunday night: Partly cloudy overall, with the slightest chance for a stray shower, still. Lows may range from the mid-50s to mid-60s with a hint of humidity. Confidence: Medium [...] Today (Friday): Sun with pleasantly warm upper 70s to low 80s — perhaps a few mid-80s in the warmest spots. A light breeze from the north and low humidity (dew points in the 50s) makes it fantastic and easy to enjoy an averagely warm September day. Confidence: High 😎 Nice Day!\\n\\nTonight: Another great evening with calm winds and temperatures in the 70s. Predawn lows dip from near 50 in cooler spots to around 60 downtown. Confidence: High [...] Tomorrow (Saturday): Wonderful weather continues, just a hair warmer, with highs near 80 to mid-80s. Still no real humidity to speak of and plenty of sun. Confidence: High 😎 Nice Day!\\n\\nTomorrow night: Partly cloudy at times with slightly warmer lows in the mid-50s to as warm as mid-60s downtown. Confidence: Medium-High", "raw_content": null}], "response_time": 0.94, "request_id": "944b49ab-726d-4b4b-8a50-cc8991a0a5db"}', name='tavily_search', id='b1b32f38-ea4a-4662-99d1-e90d77a131e1', tool_call_id='p0qnaxjrm')]}}
#
#
# {'chatbot': {'messages': [AIMessage(content='It appears that the current weather information for Bangalore is not available in the search results. However, the search results provide information about the weather in other locations, such as Washington D.C.\n\nTo get the current weather information for Bangalore, I would suggest trying a different search query or using a different weather forecasting service.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 3378, 'total_tokens': 3441, 'completion_time': 0.13154579, 'prompt_time': 0.222721809, 'queue_time': 0.05338444, 'total_time': 0.354267599}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--f205bb57-e706-4cac-b04b-b252c401148d-0', usage_metadata={'input_tokens': 3378, 'output_tokens': 63, 'total_tokens': 3441})]}}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

#Stream the events as they happen inside the node, not at the end of the node! And use latest version - v2.  
events = app.astream_events(input=input, version="v2")

# Async is used because this is an asynchronous operation.
async for event in events: 
    print(event, "\n\n")
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': 'LangGraph', 'tags': [], 'run_id': '2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'metadata': {}, 'parent_ids': []}
#
#
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='c9d5809f-83aa-4b6f-b05a-a307228f6ff7')]}}, 'name': 'chatbot', 'tags': ['graph:step:1'], 'run_id': 'b9729b18-5637-4bfb-8e66-178450db14e6', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823'}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8']}
#
#
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='c9d5809f-83aa-4b6f-b05a-a307228f6ff7')]]}}, 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='I', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content="'m", additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' functioning', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' properly', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' thank', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' asking', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' What', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' can', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' I', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' help', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' today', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='?', additional_kwargs={}, response_metadata={}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441')}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand'}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441', usage_metadata={'input_tokens': 1792, 'output_tokens': 19, 'total_tokens': 1811})}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content="I'm functioning properly, thank you for asking. What can I help you with today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand'}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441', usage_metadata={'input_tokens': 1792, 'output_tokens': 19, 'total_tokens': 1811}), 'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='c9d5809f-83aa-4b6f-b05a-a307228f6ff7')]]}}, 'run_id': '0c308324-472c-42d0-a5f9-e6ce7ff46441', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7, 'LANGSMITH_PROJECT': 'module4-building-agents-with-langgraph', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'f41a945-dirty'}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='c9d5809f-83aa-4b6f-b05a-a307228f6ff7'), AIMessage(content="I'm functioning properly, thank you for asking. What can I help you with today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand'}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441', usage_metadata={'input_tokens': 1792, 'output_tokens': 19, 'total_tokens': 1811})]}}, 'name': 'tools_condition', 'tags': ['seq:step:3'], 'run_id': 'e0ba8fba-6436-41a2-95e8-d197141ee4f4', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823'}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='c9d5809f-83aa-4b6f-b05a-a307228f6ff7'), AIMessage(content="I'm functioning properly, thank you for asking. What can I help you with today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand'}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441', usage_metadata={'input_tokens': 1792, 'output_tokens': 19, 'total_tokens': 1811})]}}, 'run_id': 'e0ba8fba-6436-41a2-95e8-d197141ee4f4', 'name': 'tools_condition', 'tags': ['seq:step:3'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'LANGSMITH_PROJECT': 'module4-building-agents-with-langgraph', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'f41a945-dirty'}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'b9729b18-5637-4bfb-8e66-178450db14e6']}
#
#
# {'event': 'on_chain_stream', 'run_id': 'b9729b18-5637-4bfb-8e66-178450db14e6', 'name': 'chatbot', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823'}, 'data': {'chunk': {'messages': [AIMessage(content="I'm functioning properly, thank you for asking. What can I help you with today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand'}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441', usage_metadata={'input_tokens': 1792, 'output_tokens': 19, 'total_tokens': 1811})]}}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8']}
#
#
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="I'm functioning properly, thank you for asking. What can I help you with today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand'}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441', usage_metadata={'input_tokens': 1792, 'output_tokens': 19, 'total_tokens': 1811})]}, 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='c9d5809f-83aa-4b6f-b05a-a307228f6ff7')]}}, 'run_id': 'b9729b18-5637-4bfb-8e66-178450db14e6', 'name': 'chatbot', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6b80df8b-1c9f-07a0-fd0c-a430595f1823', 'LANGSMITH_PROJECT': 'module4-building-agents-with-langgraph', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'f41a945-dirty'}, 'parent_ids': ['2f007ed3-3d05-414d-b4e1-03e0cabed2c8']}
#
#
# {'event': 'on_chain_stream', 'run_id': '2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'chatbot': {'messages': [AIMessage(content="I'm functioning properly, thank you for asking. What can I help you with today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand'}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441', usage_metadata={'input_tokens': 1792, 'output_tokens': 19, 'total_tokens': 1811})]}}}, 'parent_ids': []}
#
#
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='c9d5809f-83aa-4b6f-b05a-a307228f6ff7'), AIMessage(content="I'm functioning properly, thank you for asking. What can I help you with today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_55d70a61e4', 'service_tier': 'on_demand'}, id='run--0c308324-472c-42d0-a5f9-e6ce7ff46441', usage_metadata={'input_tokens': 1792, 'output_tokens': 19, 'total_tokens': 1811})]}}, 'run_id': '2f007ed3-3d05-414d-b4e1-03e0cabed2c8', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'parent_ids': []}

# %%
input = {
    "messages": ["Hi, how are you? Tell me everything!"]
}

#Stream the events as they happen inside the node, not at the end of the node!
events = app.astream_events(input=input, version="v2")

#We are only interested in the streams emitted by the LLM - on_chat_model_stream
async for event in events: 
    if event["event"] == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="", flush=True) #Flush everything from the buffer as and when some value is stored in it
        
#We can also add langgraph_node as a condition, and then stream to the UI!
# Out:
# I'm not capable of experiencing emotions or having personal feelings like humans do. However, I'm functioning properly and ready to assist you with information and tasks.
#
# If you're looking for a detailed response, I'll provide you with some general information about various topics. Would you like to know about a specific subject or area of interest?
